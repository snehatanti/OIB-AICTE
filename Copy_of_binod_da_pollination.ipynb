# %% [markdown]
# <a href="https://colab.research.google.com/github/snehatanti/OIB-AICTE/blob/main/Copy_of_binod_da_pollination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pip install pandas openpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 83.5 MB/s eta 0:00:00
# ...
#   Created wheel for openpy: filename=openpy-0.0.2-py2.py3-none-any.whl size=2781 sha256=197e9cbea97c670eca22fae00c92897e042a4622266fc8deb963e2c21fb947e5
#   Stored in directory: /root/.cache/pip/wheels/61/0d/22/e49665cdfe5301c5c8fcae8ccfe5b452f9b0da42f731a6525f
# Successfully built openpy
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
file='C:\\Users\\panka\\Downloads\\binod 3.xlsx'
df1=pd.read_excel("/content/binod 3.xlsx")
df1.head()
# Out:
#   Unnamed: 0   Unnamed: 1   Unnamed: 2 Unnamed: 3   Unnamed: 4
# 0       Year  Lepidoptera  Hymenoptera  Blattodea  Colleoptera
# 1       2013          667          384         34           71
# 2       2014          638          377         31           69
# 3       2015          623          365         33           77
# 4       2016          607          371         39           63

# %%
file1="C:\\Users\\panka\\Downloads\\binod 2.xlsx"
df2=pd.read_excel("/content/binod 2.xlsx")
df2.head()
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0  Pollinators Order       June       July     August  September    October
# 1        Lepidoptera        289        383        435        407        313
# 2        Hymenoptera        181        201        226        206        143
# 3        Colleoptera         34         49         53         57         41
# 4          Blattodea         13         61         68         65         49

# %%
file2="C:\\Users\\panka\\Downloads\\binod 1.xlsx"
df3=pd.read_excel("/content/binod 1.xlsx")
df3.head()
# Out:
#            Unnamed: 0   Unnamed: 1   Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0         Pollinators  16.30-18.30  18.30-20.30  20.30-22.30  22.30-0.30
# 1      Amata passalis            5            3            0           0
# 2  Bastilla simillima            0            1            4           7
# 3    Botyode sasialis            0            1            5           4
# 4  Chabula acamasalis            0            3            3           2
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0  0.30-2.30  2.30-4.30  4.30-6.30
# 1          0          0          2
# 2          5          2          0
# 3          4          2          0
# 4          1          0          0

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df1.columns = ['Year', 'Lepidoptera', 'Hymenoptera', 'Blattodea','Colleoptera']

# %%
df1.head()
# Out:
#    Year  Lepidoptera  Hymenoptera  Blattodea  Colleoptera
# 0  Year  Lepidoptera  Hymenoptera  Blattodea  Colleoptera
# 1  2013          667          384         34           71
# 2  2014          638          377         31           69
# 3  2015          623          365         33           77
# 4  2016          607          371         39           63

# %%
#graph with regression line using df1

import altair as alt
df1 = df1[df1.Year != 'Year']
df1 = df1.astype({'Lepidoptera':'int', 'Hymenoptera':'int', 'Blattodea':'int', 'Colleoptera':'int'})
alt.Chart(df1).mark_circle(size=60).encode(
    x='Lepidoptera',
    y='Hymenoptera',
    color='Year'
).interactive() + alt.Chart(df1).transform_regression('Lepidoptera', 'Hymenoptera').mark_line().encode(
    x='Lepidoptera',
    y='Hymenoptera'
)
# Out:
# alt.LayerChart(...)

# %%
#graph with regression line using df1

import altair as alt
df1 = df1[df1.Year != 'Year']
df1 = df1.astype({'Lepidoptera':'int', 'Hymenoptera':'int', 'Blattodea':'int', 'Colleoptera':'int'})
alt.Chart(df1).mark_circle(size=60).encode(
    x='Lepidoptera',
    y='Hymenoptera',
    color='Year'
).interactive() + alt.Chart(df1).transform_regression('Lepidoptera', 'Hymenoptera').mark_line().encode(
    x='Lepidoptera',
    y='Hymenoptera'
)
# Out:
# alt.LayerChart(...)

# %%
import altair as alt
df1 = df1[df1.Year != 'Year']
df1 = df1.astype({'Lepidoptera':'int', 'Hymenoptera':'int', 'Blattodea':'int', 'Colleoptera':'int'})
alt.Chart(df1).mark_circle(size=60).encode(
    x='Lepidoptera',
    y='Hymenoptera',
    color='Year'
).interactive() + alt.Chart(df1).transform_regression('Blattodea', 'Hymenoptera').mark_line().encode(
    x='Blattodea',
    y='Hymenoptera'
).interactive() + alt.Chart(df1).transform_regression('Colleoptera', 'Hymenoptera').mark_line().encode(
    x='Colleoptera',
    y='Hymenoptera'
)
# Out:
# alt.LayerChart(...)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
df2.columns = ['Pollinators Order', 'June', 'July', 'August','September','October']
df2.head()
# Out:
#    Pollinators Order  June  July  August  September  October
# 0  Pollinators Order  June  July  August  September  October
# 1        Lepidoptera   289   383     435        407      313
# 2        Hymenoptera   181   201     226        206      143
# 3        Colleoptera    34    49      53         57       41
# 4          Blattodea    13    61      68         65       49

# %%
#Time series analysis
import pandas as pd
print(df2)
print(type(df2))

df2 = df2.reset_index(drop=True)
df2 = df2.set_index(df2.columns[0]) # Set the first column as index
df2=df2.dropna(how='all')
df2.head()
# Out:
#                    June  July  August  September  October
# Pollinators Order
# Pollinators Order  June  July  August  September  October
# Lepidoptera         289   383     435        407      313
# Hymenoptera         181   201     226        206      143
# Colleoptera          34    49      53         57       41
# Blattodea            13    61      68         65       49
# Diptera               7     8       9         13       13
# Dictyoptera           3     5      10          9        3
# Hemiptera             1     6       8          8        5
# Orthoptera            2    13      15         17       13
# Odonata               7     9      11         13        7
# <class 'pandas.core.frame.DataFrame'>
#       July  August  September  October
# June
# June  July  August  September  October
# 289    383     435        407      313
# 181    201     226        206      143
# 34      49      53         57       41
# 13      61      68         65       49

# %%
df2.describe()
# Out:
#         July  August  September  October
# count     10      10         10       10
# unique    10      10          9        9
# top     July  August         13       13
# freq       1       1          2        2

# %%
#monthly pollination pattern analysis

import pandas as pd
#df2['Pollinators Order'] = df2['Pollinators Order'].astype(str)
df2['June'] = pd.to_numeric(df2['June'], errors='coerce') # Handle non-numeric values
df2['July'] = pd.to_numeric(df2['July'], errors='coerce')
df2['August'] = pd.to_numeric(df2['August'], errors='coerce')
df2['September'] = pd.to_numeric(df2['September'], errors='coerce')
df2['October'] = pd.to_numeric(df2['October'], errors='coerce')
# Calculate the total pollinators for each month
monthly_totals = df2[['June', 'July', 'August', 'September', 'October']].sum()

# a bar chart to visualize the monthly pollination pattern
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.bar(monthly_totals.index, monthly_totals.values)
plt.xlabel('Month')
plt.ylabel('Total Pollinators')
plt.title('Monthly Pollination Pattern')
plt.show()

# Calculate the percentage change in pollination from June to October
percentage_change = (df2['October'].sum() - df2['June'].sum()) / df2['June'].sum() * 100

print(f'Percentage change in pollination from June to October: {percentage_change:.2f}%')

# Find the month with the highest number of pollinators
max_month = monthly_totals.idxmax()
print(f'Month with the highest number of pollinators: {max_month}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'June'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-fb6c70192ee2> in <cell line: 5>()
#       3 import pandas as pd
# ...

# %%
df3.columns
df3.head()
# Out:
#           Pollinators  16.30-18.30  18.30-20.30  20.30-22.30  22.30-0.30  \
# 0         Pollinators          NaN          NaN          NaN         NaN
# 1      Amata passalis          5.0          3.0          0.0         0.0
# 2  Bastilla simillima          0.0          1.0          4.0         7.0
# 3    Botyode sasialis          0.0          1.0          5.0         4.0
# 4  Chabula acamasalis          0.0          3.0          3.0         2.0
#
#    0.30-2.30  2.30-4.30  4.30-6.30  Cluster
# 0        NaN        NaN        NaN        0
# 1        0.0        0.0        2.0        0
# 2        5.0        2.0        0.0        2
# 3        4.0        2.0        0.0        2
# 4        1.0        0.0        0.0        0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_37['16.30-18.30'].plot(kind='hist', bins=20, title='16.30-18.30')
# ...

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
df3.head()
# Out:
#            Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         Pollinators         NaN         NaN         NaN         NaN
# 1      Amata passalis         5.0         3.0         0.0         0.0
# 2  Bastilla simillima         0.0         1.0         4.0         7.0
# 3    Botyode sasialis         0.0         1.0         5.0         4.0
# 4  Chabula acamasalis         0.0         3.0         3.0         2.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN
# 1         0.0         0.0         2.0
# 2         5.0         2.0         0.0
# 3         4.0         2.0         0.0
# 4         1.0         0.0         0.0

# %%
df3.columns = ['Pollinators', '16.30-18.30', '18.30-20.30', '20.30-22.30','22.30-0.30','0.30-2.30','2.30-4.30','4.30-6.30']
df3.head()
# Out:
#           Pollinators  16.30-18.30  18.30-20.30  20.30-22.30  22.30-0.30  \
# 0         Pollinators          NaN          NaN          NaN         NaN
# 1      Amata passalis          5.0          3.0          0.0         0.0
# 2  Bastilla simillima          0.0          1.0          4.0         7.0
# 3    Botyode sasialis          0.0          1.0          5.0         4.0
# 4  Chabula acamasalis          0.0          3.0          3.0         2.0
#
#    0.30-2.30  2.30-4.30  4.30-6.30
# 0        NaN        NaN        NaN
# 1        0.0        0.0        2.0
# 2        5.0        2.0        0.0
# 3        4.0        2.0        0.0
# 4        1.0        0.0        0.0

# %%
# No Cluster pollinators based on their activity patterns.

import pandas as pd
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
X = df3.drop('Pollinators', axis=1)

imputer = SimpleImputer(strategy='mean')  # Replace missing values with the mean of the column
X_imputed = imputer.fit_transform(X)
#Determine the optimal number of clusters using the elbow method
inertia = []
for i in range(1, 11):
   kmeans = KMeans(n_clusters=i, random_state=42)
   kmeans.fit(X_imputed)
   inertia.append(kmeans.inertia_)
#Plot the elbow method graph
import matplotlib.pyplot as plt
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

kmeans = KMeans(n_clusters=3, random_state=42)
df3['Cluster'] = kmeans.fit_predict(X_imputed)
print(df3)
# Out:
#                 Pollinators  16.30-18.30  18.30-20.30  20.30-22.30  \
# 0               Pollinators          NaN          NaN          NaN
# 1            Amata passalis          5.0          3.0          0.0
# 2        Bastilla simillima          0.0          1.0          4.0
# 3          Botyode sasialis          0.0          1.0          5.0
# 4        Chabula acamasalis          0.0          3.0          3.0
# 5          Diaphania indica          5.0          8.0         11.0
# 6        Diaphnia hyalinata          3.0          6.0          9.0
# 7              Elophila spp          1.0          5.0          5.0
# 8        Glyphodes bicolour          0.0          1.0          2.0
# 9      Glyphodes bivitralis          0.0          2.0          2.0
# 10         Herpetogamma spp          1.0          3.0          7.0
# 11        Hippotion celerio         13.0         11.0          7.0
# 12      Hydridids ornatalis          3.0          3.0          2.0
# ...

# %%
# a statistical test such as ANOVA to determine if there are any significant differences

df_melt = df3.melt(id_vars=['Pollinators'], value_vars=['16.30-18.30', '18.30-20.30', '20.30-22.30', '22.30-0.30', '0.30-2.30', '2.30-4.30', '4.30-6.30'], var_name='Time', value_name='Count')

# Perform one-way ANOVA
import statsmodels.formula.api as sm
from statsmodels.stats.anova import anova_lm
model = sm.ols('Count ~ Time', data=df_melt).fit()
anova_table = anova_lm(model, typ=2)

print(anova_table)
# Out:
#                sum_sq     df         F        PR(>F)
# Time       623.726708    6.0  9.080934  3.614758e-09
# Residual  3605.978261  315.0       NaN           NaN

# %%
# 1. Calculate the average activity of each pollinator across all time intervals.
for col in df3.columns[1:]:
    df3[col] = pd.to_numeric(df3[col], errors='coerce')

# Calculate the mean for numeric columns only
df3.iloc[:, 1:].mean()
# Out:
# 16.30-18.30    4.565217
# 18.30-20.30    3.913043
# 20.30-22.30    3.586957
# 22.30-0.30     2.695652
# 0.30-2.30      1.673913
# 2.30-4.30      0.673913
# 4.30-6.30      1.043478
# Cluster        0.510638
# dtype: float64

# %%
df3.sum()
# Out:
# Pollinators    PollinatorsAmata passalisBastilla simillimaBot...
# 16.30-18.30                                                210.0
# 18.30-20.30                                                180.0
# 20.30-22.30                                                165.0
# 22.30-0.30                                                 124.0
# 0.30-2.30                                                   77.0
# 2.30-4.30                                                   31.0
# 4.30-6.30                                                   48.0
# Cluster                                                       24
# dtype: object

# %%
df3.head()
# Out:
#           Pollinators  16.30-18.30  18.30-20.30  20.30-22.30  22.30-0.30  \
# 0         Pollinators          NaN          NaN          NaN         NaN
# 1      Amata passalis          5.0          3.0          0.0         0.0
# 2  Bastilla simillima          0.0          1.0          4.0         7.0
# 3    Botyode sasialis          0.0          1.0          5.0         4.0
# 4  Chabula acamasalis          0.0          3.0          3.0         2.0
#
#    0.30-2.30  2.30-4.30  4.30-6.30  Cluster
# 0        NaN        NaN        NaN        0
# 1        0.0        0.0        2.0        0
# 2        5.0        2.0        0.0        2
# 3        4.0        2.0        0.0        2
# 4        1.0        0.0        0.0        0

# %%
# prompt: Using dataframe df3: provide the code where it will show the growth of the pollinators with respect to the time given also suggest which graph is suitable.

# This dataset is not structured in a way that easily supports plotting growth over time.
# The time columns appear to represent distinct time windows rather than a continuous timeline.
# To visualize the distribution of pollinators across these time windows, you could consider a heatmap.

import altair as alt

df3_melted = df3.melt(id_vars=['Pollinators'], value_vars=['16.30-18.30', '18.30-20.30', '20.30-22.30', '22.30-0.30', '0.30-2.30', '2.30-4.30', '4.30-6.30'],
                      var_name='Time Window', value_name='Count')

alt.Chart(df3_melted).mark_rect().encode(
    x='Time Window:O',
    y='Pollinators:O',
    color='Count:Q'
)
# Out:
# alt.Chart(...)
